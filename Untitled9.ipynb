# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive'
# /content/drive/MyDrive

# %%
ls
# Out:
# '1060_Mathematics MA1101.pdf'
#  1060.pdf
# '1060_Saketh Bettakonda_CH1101_chemistry.pdf'
# '1060_Saketh Bettakonda_chemistry_CH1101 (1).pdf'
# '1060_Saketh Bettakonda_chemistry_CH1101.gdoc'
# '1060_Saketh Bettakonda_chemistry_CH1101.pdf'
# '1060_Saketh Bettakonda_Electrical engineering_ EE1101.pdf'
# '1060_Saketh Bettakonda_Environmental science_ CE1101.pdf'
# '1060_Saketh Bettakonda_french language and culture_HS1103.pdf'
# '1060_Saketh Bettakonda_Mathematics_MA1101_justification sheets (1).pdf'
# '1060_Saketh Bettakonda_Mathematics_MA1101_justification sheets.pdf'
# '1060_Saketh Bettakonda_Themodynamics_ME1101.pdf'
# '10th certificate.pdf'
# '1-1, 1-2 sem SUPPLY (2020-BATCH) (1).pdf'
#  16685786002624055154598026011888.jpg
# '19121A0392_Fluid Mechanics.pdf'
# '19121A0392_Machine tools.pdf'
# '19121A0392_ Metrology Assignment.pdf'
# '19121A0392_Thermal Engineering.pdf'
#  2025a52312ace73f358477fef417f422.pdf
#  4841.pdf.pdf
# 'A1_1060_Bettakonda Saketh_tutorial05.pdf'
# 'A1_1060_Bettakonda Saketh_tutorial sheet 6.pdf'
#  A1_1060_SakethBettakonda_Assignment3.pdf
# 'A1_1060_Saketh Bettakonda_CE1101_assignment2 (1).pdf'
# 'A1_1060_Saketh Bettakonda_CE1101_assignment2.pdf'
# 'A1_1060_Saketh Bettakonda_CE1101_Minor2_answer sheet.pdf'
# 'A1_1060_Saketh Bettakonda_CH1101_Minor2 solutions.pdf'
# 'A1_1060_Saketh Bettakonda_EE1101_Minor 2_Answer Sheet.pdf'
# 'A1_1060_Saketh Bettakonda_EE1101tutorial 9_ 3question solution.pdf'
# 'A1_1060_Saketh Bettakonda_English_HS1101_Minor2_Answer sheet.pdf'
# 'A1_1060_Saketh Bettakonda_MA1101 assignment 2.pdf'
# 'A1_1060_Saketh Bettakonda_MA1101_Minor2 Answers.pdf'
# 'A1_1060_Saketh Bettakonda_MA1101_Minor2justifications.pdf'
# 'A1_1060_Saketh Bettakonda_ME1101_Minor2_Answer Sheet.pdf'
# 'A1_1060_Saketh Bettakonda_Themodynamics_ME1101_tutorial sheet10.pdf'
# 'A1_1060_Saketh Bettakonda_tutorial12.pdf'
# 'A1_1060_Saketh Bettakonda_tutorial sheet10.pdf'
# 'A1_1060_Saketh Bettakonda_tutorial sheet5.pdf'
# 'A1_1060_Saketh Bettakonda_tutorial sheet6.pdf'
# 'A1_1060_Saketh Bettakonda_tutorial sheet 7 (1).pdf'
# 'A1_1060_Saketh Bettakonda_tutorial sheet 7.pdf'
# 'A1_1060_Saketh Bettakonda_tutorial sheet 8.pdf'
#  AAA.pdf
# 'Aadhar card.pdf'
#  ABC.pdf
#  AFeePaymentReceiptForStudent.pdf
#  AI032.zip
#  AI032.zip.zip
#  A.pdf
# 'Ather 2023 OC (1).pdf'
# 'Ather 2023 OC.pdf'
#  b.pdf
# 'Cellular respiration discription.docx'
# 'Colab Notebooks'/
# 'Control Theory_SE20UARI032.py'
# 'Copy of yolov4.weights'
#  CourseRegistrationProfile2023-08-14_08_53_49.pdf
# 'covid report.pdf'
# 'C.Swapnika_SE20UARI045_Assignment 2.pdf'
# 'CT Scan report.pdf'
#  CYT2116036_MrBSAKETH.pdf
#  d4d2ca9a_192b_4cc7_9186_6d339e854f85.pdf
# 'Dedeepya Sree Social homework.pdf'
#  DM.pdf
# 'DR Drake.pdf'
# 'driving license.pdf'
# 'FeePaymentReceiptForStudent (1).pdf'
#  FeePaymentReceiptForStudent.pdf
# 'Good life_ Saketh Bettakonda_ SE20UARIO32_ETHICS.pdf'
# 'G.Saketh Rao_SE20UARI032_A8_Tutorial Sheet 4.pdf'
# 'GWES0673 (2).pdf'
# 'HOSTEL FORM (1).pdf'
# 'HOSTEL FORM.pdf'
# 'HW Sheet 2.pdf'
# 'india_v s_pakistan.pdf'
#  Lab5_se20ucse172_se20ucse187.pdf
#  LLR.pdf
# 'logistics 2.gsheet'
# 'logistics applications.gsheet'
# 'Logistics forms.gsheet'
# 'LOGISTICS Volunteer(AIRO).gsheet'
# 'Logistics Volunteers.gsheet'
# 'MA1101 T4.pdf'
# 'Maths summer homework Dedeepya Sree 4A.pdf'
# 'OBIP7817 (2).pdf'
#  P1.pdf
# 'pan card.pdf'
#  Passport.pdf
#  payment.jpeg
# 'Person 1.docx'
# 'physics assignment 1.pdf'
# 'physics assignment.pdf'
# 'Presentation13 (1).pptx'
#  Presentation13.pptx
# 'Project (1).gsite'
#  Project.gsite
# 'Ready Reckoner_AY2020.pdf'
# 'recharge .pdf'
# 'Regular Major exam 2020 batch MU_June 2021_TT (1).pdf'
# 'resume (1).pdf'
#  resume.pdf
# 'rtpcr 1.pdf'
# 'Saketh Bettakonda_A8_SE20UARI032_Tutorial sheet 3.pdf'
# 'Saketh Bettakonda_SE20UARI032 (1).pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_BI1201 Biology_End sem Answer sheet.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_CS1201 END SEM_Answer Sheet.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_DMS assignment.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_EE1202 END SEM _ANS SHEET.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_EEtutorial4.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_EE TUTORIAL-8.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_EE TUTORIAL 9.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_HS1204_Economics End Sem_Answer Sheet.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_MA1202_END SEM ANSWER SHEET.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_Maths Assignment.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_PH1202_End Sem Answer sheet.pdf'
# 'Saketh Bettakonda_ SE20UARI032_A8_Tutorial sheet 5.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_Tutorial sheet 6.pdf'
# 'Saketh Bettakonda_SE20UARI032_A8_Tutorial sheet 6 .pdf'
# 'Saketh Bettakonda_SE20UARI032_Accounts Assignment-converted.pdf'
# 'Saketh Bettakonda_SE20UARI032_Accounts Assignment.pdf'
# 'Saketh Bettakonda_SE20UARI032_Assignment 1_AI 1.pdf'
# 'Saketh Bettakonda_SE20UARI032_Assignment_A8.pdf'
# 'Saketh Bettakonda_SE20UARI032_CE1101_End Sem Answer sheet.pdf'
# 'Saketh Bettakonda_SE20UARI032_CH1101_End Sem Answer sheet.pdf'
# 'Saketh Bettakonda_SE20UARI032_EE1101_End sem answer sheet.pdf'
# 'Saketh Bettakonda_SE20UARI032_Engineering diagram_assignment 1.pdf'
# 'Saketh Bettakonda_SE20UARI032_HS1101_End Sem Answer sheet.pdf'
# 'Saketh Bettakonda_SE20UARI032_HS1103_End Sem Answer sheet.pdf'
# 'Saketh Bettakonda_SE20UARI032_MA1101_Assignment5.pdf'
# 'Saketh Bettakonda_SE20UARI032_MA1101_End Sem answer sheet.pdf'
# 'Saketh Bettakonda_SE20UARI032_ME1101_End Sem answer sheet.pdf'
# 'Saketh Bettakonda_SE20UARI032_Media Project.pdf'
# 'Saketh Bettakonda_SE20UARI032.pdf'
# 'Saketh Bettakonda_SE20UARI032_Signals and systems_tutorial sheet-1.pdf'
# 'Saketh Bettakonda_SE20UARI032_signals and systems_tutorial sheet 2.pdf'
# 'Saketh Bettakonda_SE20UARI032_Tutorial sheet 4.pdf'
# 'Saketh Bettakonda_SE20UARI032_Tutorial sheet 4 .pdf'
# 'Saketh Bettakonda_SE20UARI032_Tutorial sheet 5_A8.pdf'
# 'saketh SE20UARI032.pdf'
# 'S.Anushika_SE20UARI134_A10_tutorial sheet.pdf'
# 'science holiday homework Dedeepya Sree 4 A.pdf'
# 'SE20UARI032 (1).pdf'
# 'SE20UARI032-Bettakonda Saketh-LAB7.pdf'
#  SE20UARI032_HPC_ASSIGNMENT6/
# 'SE20UARI032_LAB6_Saketh Bettakonda_A8.pdf'
# 'SE20UARI032_NLP ASSIGNMENT 2.pdf'
#  SE20UARI032.pdf
# 'SE20UARI032_Saketh Bettakonda_A8_eco project..docx'
# 'SE20UARI032_Saketh Bettakonda_A8_eco project..pdf'
# 'SE20UARI032_Saketh Bettakonda_A8_tutorial sheet -6.pdf'
# 'SE20UARI032_Saketh Bettakonda_A8_tutorial sheet.pdf'
# 'SE20UARI032_Saketh Bettakonda Lab Sheet5.pdf'
# 'SE20UARI032_TUTORIAL 3_ MA2103.pdf'
# 'Se20UARI032_Tutorial sheet 1_EE1202.pdf'
# 'SE20UARI032_Tutorial sheet 3_signals and system_A8.pdf'
#  se20uari032.zip
# 'SE20UARI059_Saketh Rao.G_tutorial 4.pdf'
# 'SE20UARI134_NLP ASSIGNMENT 2.pdf'
#  SE20UARI152_Assign6.zip
#  SE20UARI155_Assign6.zip
# 'SE20UARIO32_A8_Bettakonda Saketh_EE1202 T7.pdf'
# 'SE20UCSE050_Tutorial sheet 3.pdf'
# 'SE20UECE106_GANESH_A5_TUTORIAL 6.pdf'
# 'Social holiday homework Dedeepya Sree 4 A.pdf'
# 'the boy who fell from the sky.pdf'
#  Timetable-Spring2021.pdf
# 'tutorial 2 -assignment 2 SE20UARI032-A8 -Saketh Bettakonda.pdf'
# 'tutorial sheet 5.pdf'
# 'twist (1).gdoc'
# 'twist (1).pdf'
#  twist2.pdf
#  twist.gdoc
# 'twist is ready'
#  twist.pdf
# 'Untitled form.gform'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet.gsheet'
# ' vaccine certificate (2).pdf'
# 'VI MATHS NCERT TEXTBOOK 2023-24 EDITION.pdf'
# 'volunteer tshirt form.gform'
#  WIN_20210611_10_03_49_Pro_Trim.mp4

# %%
import cv2
import time
import numpy as np
from google.colab.patches import cv2_imshow

confidence = 0.6
Nms= 0.3
class_names = []
with open("Copy of coco.names", "r") as f:
  class_names = [cname.strip() for cname in f.readlines()]
img = cv2.imread("Copy of image.jpg")
arc = cv2.dnn.readNet("Copy of yolov4.weights","Copy of yolov4.cfg")
arc.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
arc.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA_FP16)
model = cv2.dnn_DetectionModel(arc)
model.setInputParams(size=(640,640), scale=1/255, swapRB=True)
x =time.time()
classes, scores, boxes = model.detect(img, confidence, Nms)
y= time.time()
fps=1/(y-x)
for (classid, score, box) in zip(classes, scores, boxes):
  if isinstance(classid, (list, np.ndarray)):
    classid_value = classid[0]
  else:
    classid_value = classid
# Check if score is a list or a scalar
  if isinstance(score, (list, np.ndarray)):
    score_value = score[0]
  else:
    score_value = score
    label = "%s : %.2f" % (class_names[classid_value], score_value)
    cv2.rectangle(img,box,color=(255, 200, 10),thickness=2)
    cv2.putText(img, label, (box[0],box[1]-10),cv2.FONT_HERSHEY_SIMPLEX,0.6,(25,55,255),2)
    cv2.putText(img, "FPS:{0:.2f}".format(fps),(20, 25), cv2.FONT_HERSHEY_PLAIN,fontScale=2,color=(255, 0, 0),thickness=2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
